# %% [markdown]
# <a href="https://colab.research.google.com/github/Sristita2023/mypythonprojects/blob/main/Copy_of_Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
from gtts import gTTS

# %%
from IPython.display import Audio

# %%
def text_to_Audio(text,language='en'):
  HS=gTTS(text=text,lang=language)
  HS.save("output_aud.mp3")
  text="kahani shuno kahani shuno hume prayr hua tha"

# %%
text_to_Audio ("kahani shuno kahani shuno hume prayr hua tha")
Audio("output_aud.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install pydub

# %%
# !pip install AudioSegment

# %%
from IPython.lib.display import Audio
from pydub import AudioSegment

# %%
sound1 = AudioSegment.from_file('/content/drive/MyDrive/Sample.mp3')
sound2 = AudioSegment.from_file('/content/output_aud.mp3')

# %%
combined=sound2.overlay(sound1)
combined.export("combined.Wav",format='Wav')
# Out:
# <_io.BufferedRandom name='combined.Wav'>

# %%
Audio("/content/combined.Wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import drive
drive.mount('/content/drive')
